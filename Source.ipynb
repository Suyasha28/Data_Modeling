# %%
# %sql
CREATE TABLE IF NOT EXISTS DataModeling.default.sourcedata
(
    order_id INT PRIMARY KEY,
    order_date DATE,
    customer_id INT,
    customer_name STRING,
    customer_email STRING,
    product_id INT,
    product_name STRING,
    product_category STRING,
    quantity INT,
    unit_price DECIMAL(10,2),
    payment_type STRING,
    country STRING,
    last_updated DATE
);

# %%
# %sql
INSERT INTO DataModeling.default.sourcedata VALUES
(1001, '2024-07-01', 1, 'Alice Johnson', 'alice@gmail.com', 501, 'iPhone 14', 'Electronics', 1, 999.99, 'Credit Card', 'USA', '2024-07-01'),
(1002, '2024-07-01', 2, 'Bob Smith', 'bob@yahoo.com', 502, 'AirPods Pro', 'Electronics', 2, 199.99, 'PayPal', 'USA', '2024-07-01'),
(1003, '2024-07-01', 3, 'Charlie Brown', 'charlie@outlook.com', 503, 'Nike Shoes', 'Footwear', 1, 129.99, 'Credit Card', 'Canada', '2024-07-01');

# %%
# %sql
SELECT * FROM DataModeling.default.sourcedata

# %% [markdown]
# ### Add more data to perform upsert - incremental Load

# %%
# %sql
INSERT INTO datamodeling.default.sourcedata VALUES
(1004, '2024-07-02', 4, 'David Lee', 'david@abc.com', 504, 'Samsung23','Electronics', 1, 899.99, 'Credit Card', 'USA', '2024-07-02'),
(1005, '2024-07-02', 1, 'Alice Johnson', 'alice@gmail.com', 503, 'Nike Shoes', 'Footwear', 2, 129.99, 'Credit Card', 'USA', '2024-07-02');

# %%
# %sql
SELECT * FROM DataModeling.default.sourcedata
