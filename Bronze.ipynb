# %%
last_load_date = '1000-01-01'

# %%
# Select * from datamodeling.default.sourcedata where order_Date>'1000-01-01'
spark.sql(f"""
          Select * from datamodeling.default.sourcedata 
          where order_Date >'{last_load_date}' """).createOrReplaceTempView("bronze_source")

# %%
# %sql
Select * from bronze_source

# %%
# %sql
create or replace table datamodeling.bronze.bronze_table 
as
Select * from bronze_source

# %%
# %sql
Select * from bronze_source

# %% [markdown]
# ### Remove last_load_Date hardcoded , make it dynamic- fetch max date from bronze_table & get data after that date only from source

# %%
if spark.catalog.tableExists("datamodeling.bronze.bronze_table"):
    last_load_date = spark.sql("""Select max(last_updated) 
                              from datamodeling.bronze.bronze_table""")
    display(last_load_date)
else: 
    last_load_date = '1000-01-01'

spark.sql(f"""Select * from datamodeling.default.sourcedata 
          where order_date > (select max(last_updated) from datamodeling.bronze.bronze_table)""").createOrReplaceTempView("bronze_source")

# %%
# %sql
create or replace table datamodeling.bronze.bronze_table 
as
Select * from bronze_source

# %%
# %sql
Select * from datamodeling.bronze.bronze_table
